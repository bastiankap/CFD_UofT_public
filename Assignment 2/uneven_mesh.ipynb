# %%
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3]
y = [0, 1, 2, 3]
x_new = [0, 1, 1.5, 2, 2.5 ,3]
y_new = [0, 1.5, 2, 2.5, 3]
xx, yy = np.meshgrid(x, y)
z = np.sin(xx**2+yy**2)
f = interpolate.interp2d(x, y, z, kind='cubic')
print(z)
print(f(x_new, y_new))
# Out:
# [[ 0.          0.84147098 -0.7568025   0.41211849]
#  [ 0.84147098  0.90929743 -0.95892427 -0.54402111]
#  [-0.7568025  -0.95892427  0.98935825  0.42016704]
#  [ 0.41211849 -0.54402111  0.42016704 -0.75098725]]
# [[-5.13620380e-16  8.41470985e-01  2.18686200e-02 -7.56802495e-01
#   -8.43674995e-01  4.12118485e-01]
#  [ 2.18686200e-02 -4.65057190e-02 -3.03137774e-03  3.81588254e-02
#    3.65210313e-02 -4.84886191e-02]
#  [-7.56802495e-01 -9.58924275e-01  3.81588254e-02  9.89358247e-01
#    1.31118924e+00  4.20167037e-01]
#  [-8.43674995e-01 -1.30056161e+00  3.65210313e-02  1.31118924e+00
#    1.69386919e+00  3.54987085e-01]
#  [ 4.12118485e-01 -5.44021111e-01 -4.84886191e-02  4.20167037e-01
#    3.54987085e-01 -7.50987247e-01]]

# %%
xnew = np.arange(-5.01, 5.01, 1e-2)
ynew = np.arange(-5.01, 5.01, 1e-2)
znew = f(xnew, ynew)
plt.plot(x, z[0, :], 'ro-', xnew, znew[0, :], 'b-')
plt.show()
np.shape(znew)
# Out:
# (1002, 1002)

# %%
w = [1,2,3]
k = [1,2,3]

ww = []
kk = []
for j in np.arange(len(w)):
    ww = ww + w

for i in np.arange(len(k)):
    kk = kk +list(np.ones(len(k))*k[i])

print(kk,ww)
# Out:
# [1.0, 1.0, 1.0, 2.0, 2.0, 2.0, 3.0, 3.0, 3.0] [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
list(np.ones(len(k))*2)
# Out:
# [2.0, 2.0, 2.0]

# %%
pow(5,2)
# Out:
# 25
